# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

visa_df=pd.read_csv('Visadataset.csv')
visa_df.head(5)
visa_df.tail(5)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %% [markdown]
# - take has a drawback that it can get either rows or columns only
#
# - if we want both use iloc or loc indexinng
#
# - function or method has (), but inndexing has []

# %%
visa_df.iloc

# %%
visa_df.take
# Out:
# <bound method NDFrame.take of          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.iloc[<rows>,<columns>]

rows & columns can besliced

visa_df.iloc[start:stop:step,start:stop:step]

# %%
visa_df.iloc[100:105,5:8]
#rows 100 to 104 ; columns from 5 to 8
# Out:
#      no_of_employees  yr_of_estab region_of_employment
# 100             2227         2007            Northeast
# 101              334         2007              Midwest
# 102              224         2008              Midwest
# 103              367         1982                 West
# 104              306         2003            Northeast

# %%
visa_df.iloc[100:103]
# 100 to 103 rows with all columns
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 101  EZYV102      Asia              Master's                  Y
# 102  EZYV103      Asia            Bachelor's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 101                     N              334         2007              Midwest
# 102                     N              224         2008              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 101         43421.88         Year                  Y   Certified
# 102         80253.78         Year                  Y   Certified

# %%
visa_df.iloc[[100,200,300]]
# only 100,200,300 rows with all columns
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.iloc[[100,200,300],[5,7,9]]
# 100,200,300 rows only with 5,7,9 columns
# Out:
#      no_of_employees region_of_employment unit_of_wage
# 100             2227            Northeast         Year
# 200             3282                 West         Year
# 300             3268              Midwest         Year

# %%
visa_df.iloc[:,[1]]
# 1 collumn all the rows dataframe type
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 1         83425.65         Year                  Y   Certified

# %%
visa_df.iloc[:,1]
# 1 column with all rows series type
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df.iloc[:,[1]]
# 1 column with all rows dataframe type
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# - iloc & loc both are trying to retrieve rows & columns
#
# - but for columns iloc expect index
#
# - loc expect direct column names

# %%
visa_df.loc[:,['prevailing_wage','continent']]
# Out:
#        prevailing_wage continent
# 0             592.2029      Asia
# 1           83425.6500      Asia
# 2          122996.8600      Asia
# 3           83434.0300      Asia
# 4          149907.3900    Africa
# ...                ...       ...
# 25475       77092.5700      Asia
# 25476      279174.7900      Asia
# 25477      146298.8500      Asia
# 25478       86154.7700      Asia
# 25479       70876.9100      Asia
#
# [25480 rows x 2 columns]

# %% [markdown]
# **multiple values means always think about list**
#
# **any parameter say index or array  means, it is expecting a list of values**
#
# **the index values can represent as list , numpy array or tensor**
