# %% [markdown]
# **Label Encoder**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

visa_df=pd.read_csv('Visadataset.csv')
cat_cols=visa_df.select_dtypes(include='object').columns
le=LabelEncoder()
for i in cat_cols:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# 1                          0             2412         2002
# 2                          1            44444         2008
# 3                          0               98         1897
# 4                          0             1082         2005
# ...                      ...              ...          ...
# 25475                      1             2601         2008
# 25476                      0             3274         2006
# 25477                      0             1121         1910
# 25478                      1             1918         1887
# 25479                      0             3195         1960
#
#        region_of_employment  prevailing_wage  unit_of_wage  \
# 0                         4         592.2029             0
# 1                         2       83425.6500             3
# 2                         4      122996.8600             3
# 3                         4       83434.0300             3
# 4                         3      149907.3900             3
# ...                     ...              ...           ...
# 25475                     3       77092.5700             3
# 25476                     2      279174.7900             3
# 25477                     3      146298.8500             3
# 25478                     4       86154.7700             3
# 25479                     1       70876.9100             3
#
#        full_time_position  case_status
# 0                       1            1
# 1                       1            0
# 2                       1            1
# 3                       1            1
# 4                       1            0
# ...                   ...          ...
# 25475                   1            0
# 25476                   1            0
# 25477                   0            0
# 25478                   1            0
# 25479                   1            0
#
# [25480 rows x 12 columns]

# %%
visa_df=pd.read_csv('Visadataset.csv')
from sklearn.preprocessing import LabelEncoder
le.LabelEncoder()
data=le.fit_transform(visa_df['education_of_employee'])
le.inverse_transform(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 3
#       1 visa_df=pd.read_csv('Visadataset.csv')
#       2 from sklearn.preprocessing import LabelEncoder
# ----> 3 le.LabelEncoder()
#       4 data=le.fit_transform(visa_df['education_of_employee'])
#       5 le.inverse_transform(data)
#
# AttributeError: 'LabelEncoder' object has no attribute 'LabelEncoder'

# %% [markdown]
# **pd.get_dummies**

# %%
visa_df=pd.read_csv('Visadataset.csv')
pd.get_dummies(visa_df['education_of_employee'],dtype='int')
# Out:
#        Bachelor's  Doctorate  High School  Master's
# 0               0          0            1         0
# 1               0          0            0         1
# 2               1          0            0         0
# 3               1          0            0         0
# 4               0          0            0         1
# ...           ...        ...          ...       ...
# 25475           1          0            0         0
# 25476           0          0            1         0
# 25477           0          0            0         1
# 25478           0          0            0         1
# 25479           1          0            0         0
#
# [25480 rows x 4 columns]

# %% [markdown]
# **np.where**

# %%
visa_df=pd.read_csv('Visadataset.csv')
con1=visa_df['case_status']=='Certified'
true=0
false=1
np.where(con1,true,false)
# Out:
# array([1, 0, 1, ..., 0, 0, 0])
