# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


visa_df= pd.read_csv('Visadataset.csv')
con1=visa_df['continent']=='Asia'
con2=visa_df['case_status']=='Certified'
con3=con1&con2
visa_df[con3]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# 8         EZYV09      Asia            Bachelor's                  N
# 10        EZYV11      Asia              Master's                  N
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


visa_df= pd.read_csv('Visadataset.csv')
cat_cols=visa_df.select_dtypes(include='object').columns
num_cols=visa_df.select_dtypes(exclude='object').columns

cert_cnt,den_cnt,index=[],[],[]
unique_continent=visa_df['continent'].unique()
columns=visa_df['case_status'].unique()
unique_continent
for i in unique_continent:
    con1=visa_df['continent']==i
    con2=visa_df['case_status']=='Certified'
    con3=visa_df['case_status']=='Denied'
    con4=con1&con2
    con5=con1&con3
    cert_cnt.append(len(visa_df[con4]))
    den_cnt.append(len(visa_df[con5]))
    
cols=visa_df['case_status'].unique()
pd.DataFrame(zip(cert_cnt,den_cnt), columns=cols,index=unique_continent)

    
#con1=visa_df['continent']=='Asia'
#con2=visa_df['case_status']=='Certified'
#con3=con1&con2
#visa_df[con3]
# Out:
#                Denied  Certified
# Asia            11012       5849
# Africa            397        154
# North America    2037       1255
# Europe           2957        775
# South America     493        359
# Oceania           122         70

# %%
index=visa_df['continent']
cols=visa_df['case_status']
pd.crosstab(index,cols)
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
index=visa_df['continent']
cols1=visa_df['case_status']
cols2=visa_df['education_of_employee']
cols3=[cols1,cols2]
info2=pd.crosstab(index,cols3)
info2
info2.plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>

# %% [markdown]
# **scatter plots**

# %%
x=[i for i in range(10)]
y=[i for i in range(10)]
plt.scatter(x,y)
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
num_empl=visa_df['no_of_employees']
num_wage=visa_df['prevailing_wage']
plt.scatter(num_empl,num_wage)
plt.plot(num_empl,num_wage)
plt.show()

# %% [markdown]
# - increase/decrease/ no relation
